# %%
#!pip3 install pandas_datareader

# %%
#!pip3 install yfinance

# %%
#!pip3 install pandas-datareader

# %%
import numpy as np
import pandas_datareader as pdr
import datetime as dt
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
# %matplotlib notebook
import seaborn as sns
from sklearn.linear_model import LinearRegression

# %%
# tickers_2 = ['KOTAKBANK.NS', 'TATAMOTORS.NS', 'GRASIM.NS', 'COALINDIA.NS', 'SHREECEM.NS', 'EICHERMOT.NS', 'AXISBANK.NS', 'SBIN.NS','IOC.NS','BPCL.NS','UPL.NS', 'MARUTI.NS', 'SUNPHARMA.NS', 'ONGC.NS', 'BRITANNIA.NS', 'ADANIPORTS.NS', 'NESTLEIND.NS', 'TATASTEEL.NS', 'DRREDDY.NS','IPL.NS']
tickers_1 = ['ITC.NS', 'AMBUJACEM.NS', 'ADANIPORTS.NS', 'SBIN.NS','LT.NS','PATANJALI.NS','IRB.NS','FORTIS.NS','LINDEINDIA.NS','ESCORTS.NS','ZEEL.NS','CRISIL.NS','KOTAKBANK.NS','AEGISCHEM.NS','HFCL.NS','SUNPHARMA.NS','TATACOMM.NS','RELIANCE.NS','IPL.NS','CUMMINSIND.NS']
start = dt.datetime(2019, 10, 21)
data = pdr.get_data_yahoo(tickers_1, start)

# %%
data.head()
# Out:
# Attributes   Adj Close                                                      \
# Symbols         ITC.NS AMBUJACEM.NS ADANIPORTS.NS     SBIN.NS        LT.NS
# Date
# 2019-10-22  214.867920   175.591476    410.412506  263.906891  1350.745117
# 2019-10-23  216.723938   176.398178    386.368164  268.736237  1340.679565
# 2019-10-24  214.997421   177.160065    389.343231  256.101868  1341.100830
# 2019-10-25  213.832001   176.980789    389.148132  274.687561  1334.312134
# 2019-10-27  216.162827   177.070450    389.977234  274.931458  1343.113892
#
# Attributes                                                                ...  \
# Symbols    PATANJALI.NS     IRB.NS   FORTIS.NS LINDEINDIA.NS  ESCORTS.NS  ...
# Date                                                                      ...
# 2019-10-22   363.765686  68.061966  138.399994    513.481262  639.276855  ...
# 2019-10-23   358.782593  77.260818  137.199997    523.513977  649.532654  ...
# ...

# %%
data_1=data['Close']

# %%
data_1
# Out:
# Symbols         ITC.NS  AMBUJACEM.NS  ADANIPORTS.NS     SBIN.NS        LT.NS  \
# Date
# 2019-10-22  248.899994    195.899994     420.750000  270.500000  1442.550049
# 2019-10-23  251.050003    196.800003     396.100006  275.450012  1431.800049
# 2019-10-24  249.050003    197.649994     399.149994  262.500000  1432.250000
# 2019-10-25  247.699997    197.449997     398.950012  281.549988  1425.000000
# 2019-10-27  250.399994    197.550003     399.799988  281.799988  1434.400024
# ...                ...           ...            ...         ...          ...
# 2022-10-17  332.250000    520.549988     786.200012  543.650024  1883.199951
# 2022-10-18  340.299988    507.850006     809.950012  562.450012  1918.099976
# 2022-10-19  346.350006    510.700012     805.049988  553.400024  1904.900024
# 2022-10-20  349.700012    517.700012     820.049988  555.400024  1904.150024
# 2022-10-21  345.600006    512.599976     801.650024  560.849976  1876.750000
#
# ...

# %%
data_1/data_1.iloc[0]
# Out:
# Symbols       ITC.NS  AMBUJACEM.NS  ADANIPORTS.NS   SBIN.NS     LT.NS  \
# Date
# 2019-10-22  1.000000      1.000000       1.000000  1.000000  1.000000
# 2019-10-23  1.008638      1.004594       0.941414  1.018299  0.992548
# 2019-10-24  1.000603      1.008933       0.948663  0.970425  0.992860
# 2019-10-25  0.995179      1.007912       0.948188  1.040850  0.987834
# 2019-10-27  1.006027      1.008423       0.950208  1.041774  0.994350
# ...              ...           ...            ...       ...       ...
# 2022-10-17  1.334873      2.657223       1.868568  2.009797  1.305466
# 2022-10-18  1.367216      2.592394       1.925015  2.079298  1.329659
# 2022-10-19  1.391523      2.606942       1.913369  2.045841  1.320509
# 2022-10-20  1.404982      2.642675       1.949020  2.053235  1.319989
# 2022-10-21  1.388510      2.616641       1.905288  2.073383  1.300995
#
# Symbols     PATANJALI.NS    IRB.NS  FORTIS.NS  LINDEINDIA.NS  ESCORTS.NS  \
# Date
# ...

# %%
daily_simple_return = data_1/data_1.shift()
daily_simple_return.dropna(inplace=True)
fig, ax = plt.subplots(figsize=(15,8))
for i in daily_simple_return.columns.values :
    ax.plot(daily_simple_return[i], lw =2 ,label = i)


ax.legend( loc = 'upper right' , fontsize =10)
ax.set_title('Volatility in Daily simple returns ')
ax.set_xlabel('Date')
ax.set_ylabel('Daily simple returns')
plt.show(fig)

# %%
# This graph shows the volatility

# %%
print('Average Daily returns(%) of stocks in your portfolio')
Avg_daily = daily_simple_return.mean()
print(Avg_daily*100)
# Out:
# Average Daily returns(%) of stocks in your portfolio
# Symbols
# ITC.NS           100.175598
# AMBUJACEM.NS     100.148263
# ADANIPORTS.NS    100.060536
# SBIN.NS          100.094979
# LT.NS            100.080232
# PATANJALI.NS     100.126212
# IRB.NS           100.171961
# FORTIS.NS        100.060907
# LINDEINDIA.NS    100.213634
# ESCORTS.NS       100.178834
# ZEEL.NS          100.130656
# CRISIL.NS        100.054625
# KOTAKBANK.NS     100.043534
# AEGISCHEM.NS      99.995943
# HFCL.NS          100.018878
# SUNPHARMA.NS     100.124442
# TATACOMM.NS       99.987852
# RELIANCE.NS      100.057295
# IPL.NS            99.954405
# CUMMINSIND.NS    100.113614
# dtype: float64

# %%
high_low = data['High']- data ['Low']
high_closePrevious = np.abs(data['High'] - data ['Close'].shift())
low_closePrevious = np.abs(data['Low'] - data ['Close'].shift())

# %%
df1 = pd.DataFrame(pd.concat([high_low,high_closePrevious,low_closePrevious],axis=1) )

# %%
df1
# Out:
# Symbols        ITC.NS  AMBUJACEM.NS  ADANIPORTS.NS    SBIN.NS      LT.NS  \
# Date
# 2019-10-22   6.150009     12.899994      11.750000   6.500000  28.650024
# 2019-10-23   2.899994      4.699997      24.000000   9.149994  30.300049
# 2019-10-24   6.050003      4.949997       8.100006  29.000000  40.650024
# 2019-10-25  10.200012      3.800003       6.100006  20.600006  21.599976
# 2019-10-27   1.400009      1.899994       3.700012   4.700012  10.099976
# ...               ...           ...            ...        ...        ...
# 2022-10-17   5.149994     25.250000      18.299988  20.500000  35.599976
# 2022-10-18   7.450012     18.150024      24.500000  16.750000  38.099976
# 2022-10-19   7.650024     12.299988      22.299988  11.900024  45.349976
# 2022-10-20   6.150024     12.000000      27.200012  11.500000  31.500000
# 2022-10-21   8.700012     19.100037      24.799988   8.549988  57.900024
#
# Symbols     PATANJALI.NS     IRB.NS  FORTIS.NS  LINDEINDIA.NS  ESCORTS.NS  \
# Date
# ...

# %%
true_range = pd.DataFrame()

# %%
for i in tickers_1:
    true_range[i] = np.max(df1[i],axis=1)

# %%
true_range
# Out:
#                ITC.NS  AMBUJACEM.NS  ADANIPORTS.NS    SBIN.NS      LT.NS  \
# Date
# 2019-10-22   6.150009     12.899994      11.750000   6.500000  28.650024
# 2019-10-23   3.050003      4.699997      25.750000   9.149994  30.300049
# 2019-10-24   6.050003      4.949997       8.100006  29.000000  40.650024
# 2019-10-25  10.200012      3.800003       6.100006  21.649994  21.599976
# 2019-10-27   3.400009      1.899994       3.700012   4.700012  13.949951
# ...               ...           ...            ...        ...        ...
# 2022-10-17   5.149994     25.250000      18.299988  20.500000  35.599976
# 2022-10-18   8.750000     18.150024      28.799988  19.849976  48.000000
# 2022-10-19   7.650024     12.299988      22.299988  11.900024  45.349976
# 2022-10-20   6.150024     12.000000      27.200012  11.500000  31.500000
# 2022-10-21   8.700012     19.100037      24.799988  10.399963  57.900024
#
#             PATANJALI.NS     IRB.NS  FORTIS.NS  LINDEINDIA.NS  ESCORTS.NS  \
# Date
# ...

# %%
average_true_range = true_range.rolling(14).mean()

# %%
# for i in tickers:
fig, ax = plt.subplots(figsize=(30,20))
average_true_range.plot(ax=ax)
ax2 = data_1.plot(ax=ax, secondary_y=True, alpha=.3)
ax.set_ylabel("ATR")
ax2.set_ylabel("Price")
# Out:
# Text(0, 0.5, 'Price')

# %%
daily_simple_return.plot(kind = "box",figsize = (40,15), title = "Risk Box Plot")
# Out:
# <AxesSubplot:title={'center':'Risk Box Plot'}>

# %%
# Quartile range higher , higher the volatility , more the risk 
# more Positive outliers, more is the return

# %%
df2 = data['Adj Close']

# %%
portfolio=[0.1,0.088,0.085,0.074,0.073,0.065,0.052,0.05,0.05,0.05,0.045,0.042,0.04,0.038,0.037,0.034,0.025,0.022,0.02,0.01]

# %%
np.sum(portfolio)
# Out:
# 1.0

# %%
df2/df2.shift()
# Out:
# Symbols       ITC.NS  AMBUJACEM.NS  ADANIPORTS.NS   SBIN.NS     LT.NS  \
# Date
# 2019-10-22       NaN           NaN            NaN       NaN       NaN
# 2019-10-23  1.008638      1.004594       0.941414  1.018299  0.992548
# 2019-10-24  0.992034      1.004319       1.007700  0.952986  1.000314
# 2019-10-25  0.994579      0.998988       0.999499  1.072571  0.994938
# 2019-10-27  1.010900      1.000507       1.002131  1.000888  1.006596
# ...              ...           ...            ...       ...       ...
# 2022-10-17  1.000452      1.037262       1.007820  1.031203  0.985143
# 2022-10-18  1.024229      0.975603       1.030209  1.034581  1.018532
# 2022-10-19  1.017778      1.005612       0.993950  0.983910  0.993118
# 2022-10-20  1.009672      1.013707       1.018632  1.003614  0.999606
# 2022-10-21  0.988276      0.990149       0.977562  1.009813  0.985610
#
# Symbols     PATANJALI.NS    IRB.NS  FORTIS.NS  LINDEINDIA.NS  ESCORTS.NS  \
# Date
# ...

# %%
log_returns = np.log(df2/df2.shift())

# %%
log_returns.dropna(inplace=True)
log_returns
# Out:
# Symbols       ITC.NS  AMBUJACEM.NS  ADANIPORTS.NS   SBIN.NS     LT.NS  \
# Date
# 2021-07-06 -0.005663      0.033377       0.003725 -0.006725 -0.001626
# 2021-07-07  0.006154      0.015791       0.010329  0.007188  0.007247
# 2021-07-08 -0.008626      0.009190      -0.011734 -0.019597 -0.010440
# 2021-07-09 -0.003223      0.007869       0.023331 -0.001651 -0.000733
# 2021-07-12 -0.001242      0.022167      -0.014448  0.008694  0.000767
# ...              ...           ...            ...       ...       ...
# 2022-10-17  0.000452      0.036585       0.007789  0.030726 -0.014968
# 2022-10-18  0.023940     -0.024700       0.029761  0.033997  0.018363
# 2022-10-19  0.017622      0.005596      -0.006068 -0.016221 -0.006906
# 2022-10-20  0.009626      0.013614       0.018461  0.003608 -0.000394
# 2022-10-21 -0.011794     -0.009900      -0.022693  0.009765 -0.014494
#
# Symbols     PATANJALI.NS    IRB.NS  FORTIS.NS  LINDEINDIA.NS  ESCORTS.NS  \
# Date
# ...

# %%
log_return = np.sum(np.log(df2/df2.shift())*portfolio,axis=1)

# %%
fig, ax = plt.subplots(figsize=(10,8))
log_return.hist(bins=50, ax=ax)
# Out:
# <AxesSubplot:>

# %%
## if value is near zero , less is the volatility

# %%
log_return.std()
# Out:
# 0.01578376999248621

# %%
np.exp(log_return.mean())
# Out:
# 1.0010833776390013

# %%
sharpe_ratio = (log_return.mean()-0.0702/364)/log_return.std()
sharpe_ratio
# Out:
# 0.05554739161380758

# %%
asr = sharpe_ratio*(252**.5)

# %%
asr
# Out:
# 0.881787505130698

# %%
information_ratio = (log_return.mean()-(0.112/252))/log_return.std()
information_ratio
# Out:
# 0.03843192932088758

# %%
annual_infomation_ratio = information_ratio*(252**.5)
annual_infomation_ratio
# Out:
# 0.61008796432488

# %% [markdown]
# Monte Carlo Simulation

# %%
n=10000
weights = np.zeros((n,20))
exp_returns = np.zeros(n)
exp_vols = np.zeros(n)
sharpe_ratios = np.zeros(n)
information_ratios = np.zeros(n)

for i in range (n):
    weight = np.random.random(20)
    weight /= weight.sum()
    weights[i] = weight

    exp_returns[i] = np.sum((log_returns.mean()*weight))*252
    exp_vols[i] = np.sqrt(np.dot(weight.T, np.dot(log_returns.cov()*252,weight)))
    sharpe_ratios[i] = (exp_returns[i]-(0.0702/364))/exp_vols[i]
    information_ratios[i] = (exp_returns[i]-(0.112/252))/exp_vols[i]

# %%
sharpe_ratios.max()
# Out:
# 1.3466268503972245

# %%
sharpe_ratios.argmax()
# Out:
# 9572

# %%
information_ratios.max()
# Out:
# 1.345099151856449

# %%
information_ratios.argmax()
# Out:
# 9572

# %%
weights[9572]
# Out:
# array([0.09813269, 0.07163333, 0.01296681, 0.04401937, 0.00694696,
#        0.09332738, 0.00479529, 0.06095854, 0.08109546, 0.07888395,
#        0.03593493, 0.05299701, 0.02607723, 0.04045945, 0.01146871,
#        0.1037378 , 0.00847593, 0.08907718, 0.00500255, 0.07400942])

# %%
fig, ax = plt.subplots(figsize=(10,10))
ax.scatter(exp_vols,exp_returns,c=sharpe_ratios)
ax.scatter(exp_vols[sharpe_ratios.argmax()],exp_returns[sharpe_ratios.argmax()],c='red')
ax.set_xlabel('Expected Volatility')
ax.set_ylabel('Expected Returns')
# Out:
# Text(0, 0.5, 'Expected Returns')

# %%
# Red dot shows the highest Sharpe ratio

# %%
fig, ax = plt.subplots(figsize=(10,10))
ax.scatter(exp_vols,exp_returns,c=information_ratios)
ax.scatter(exp_vols[information_ratios.argmax()],exp_returns[information_ratios.argmax()],c='red')
ax.set_xlabel('Expected Volatility')
ax.set_ylabel('Expected Returns')
# Out:
# Text(0, 0.5, 'Expected Returns')

# %%
nifty50 = pdr.get_data_yahoo("^NSEI", start)
log_returns['Nifty50'] = np.log(nifty50['Adj Close']/nifty50['Adj Close'].shift())
log_returns.corr()
# Out:
# Symbols          ITC.NS  AMBUJACEM.NS  ADANIPORTS.NS   SBIN.NS     LT.NS  \
# Symbols
# ITC.NS         1.000000      0.293299       0.473817  0.406511  0.332119
# AMBUJACEM.NS   0.293299      1.000000       0.444381  0.368827  0.331384
# ADANIPORTS.NS  0.473817      0.444381       1.000000  0.488546  0.550897
# SBIN.NS        0.406511      0.368827       0.488546  1.000000  0.489588
# LT.NS          0.332119      0.331384       0.550897  0.489588  1.000000
# PATANJALI.NS   0.231481      0.197602       0.314230  0.208374  0.253085
# IRB.NS         0.222874      0.121373       0.340494  0.349312  0.279657
# FORTIS.NS      0.197930      0.230975       0.313606  0.235152  0.293573
# LINDEINDIA.NS  0.160268      0.152526       0.227416  0.234476  0.159444
# ESCORTS.NS     0.135150      0.180285       0.277550  0.206410  0.164028
# ZEEL.NS        0.257761      0.169678       0.358599  0.254766  0.286822
# CRISIL.NS      0.134283      0.191140       0.247727  0.136839  0.177444
# ...

# %%
fig1 = plt.figure(figsize=(20,20))
dataplot = sns.heatmap(log_returns.corr(),cmap='YlGnBu',annot= True)

plt.show(fig1)

# %%
# negative ratio - patanjali , nifty50

# %%
# alphas = np.zeros(len(tickers_1))
# betas = np.zeros(len(tickers_1))
# def linear_regression(ticker_a,n):
#     X = log_returns[ticker_a].to_numpy().reshape(-1, 1)
#     Y = log_returns['Nifty50'].to_numpy().reshape(-1, 1)
#     lin_regr = LinearRegression()
#     lin_regr.fit(X, Y)
#     Y_pred = lin_regr.predict(X)
#     alpha = lin_regr.intercept_[0]
#     beta = lin_regr.coef_[0, 0]
#     alphas[n]=round(alpha, 5)
#     betas[n]=round(beta, 3)
#     fig, ax = plt.subplots()
#     ax.set_title("Alpha: " + str(round(alpha, 5)) + ", Beta: " + str(round(beta, 3)))
#     ax.scatter(X, Y)
#     ax.plot(X, Y_pred, c='r')

# %%
# for i in range (len(tickers_1)):
#     linear_regression(tickers_1[i],i)

# %%
# alphas.max()

# %%
# betas.max()

# %%
cov = log_returns.cov()
var = log_returns['Nifty50'].var()
beta = cov.loc['ITC.NS', 'Nifty50']/var

# %%
# betas[0]

# %%
risk_free_return=0.0702
market_return=0.12
expected_return = risk_free_return + beta*(market_return - risk_free_return)

# %%
beta = cov.loc['Nifty50']/var
market_return = risk_free_return + beta*(market_return - risk_free_return)
market_return
# Out:
# Symbols
# ITC.NS           0.108075
# AMBUJACEM.NS     0.112997
# ADANIPORTS.NS    0.138353
# SBIN.NS          0.125922
# LT.NS            0.123563
# PATANJALI.NS     0.120338
# IRB.NS           0.126359
# FORTIS.NS        0.111686
# LINDEINDIA.NS    0.105813
# ESCORTS.NS       0.097301
# ZEEL.NS          0.129359
# CRISIL.NS        0.100169
# KOTAKBANK.NS     0.122577
# AEGISCHEM.NS     0.105682
# HFCL.NS          0.135935
# SUNPHARMA.NS     0.105232
# TATACOMM.NS      0.114489
# RELIANCE.NS      0.124153
# IPL.NS           0.123868
# CUMMINSIND.NS    0.110995
# Nifty50          0.120000
# Name: Nifty50, dtype: float64
