# %%
# !pip3 install pandas_datareader

# %%
#!pip3 install yfinance
# Out:
# ...
# [notice] A new release of pip available: 22.2.2 -> 22.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...

# %%
# !pip3 install pandas-datareader

# %%
import numpy as np
import pandas_datareader as pdr
import datetime as dt
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
# %matplotlib notebook

# %%
tickers_1 = ['ITC.NS', 'AMBUJACEM.NS', 'ADANIPORTS.NS', 'SBIN.NS','LT.NS','PATANJALI.NS','IRB.NS','FORTIS.NS','LINDEINDIA.NS','ESCORTS.NS','ZEEL.NS','CRISIL.NS','KOTAKBANK.NS','AEGISCHEM.NS','HFCL.NS','SUNPHARMA.NS','TATACOMM.NS','RELIANCE.NS','IPL.NS','CUMMINSIND.NS']
# tickers_2 = ['KOTAKBANK.NS', 'TATAMOTORS.NS', 'GRASIM.NS', 'COALINDIA.NS', 'SHREECEM.NS', 'EICHERMOT.NS', 'AXISBANK.NS', 'SBIN.NS','IOC.NS','BPCL.NS','UPL.NS', 'MARUTI.NS', 'SUNPHARMA.NS', 'ONGC.NS', 'BRITANNIA.NS', 'ADANIPORTS.NS', 'NESTLEIND.NS', 'TATASTEEL.NS', 'DRREDDY.NS']
start = dt.datetime(2019, 10, 21)
data = pdr.get_data_yahoo(tickers_1, start)
portfolio = np.random.random(20)
portfolio /= portfolio.sum()
portfolio
# Out:
# array([0.08479987, 0.03584787, 0.02006751, 0.00598681, 0.06217646,
#        0.07753385, 0.02197587, 0.07524093, 0.03238715, 0.06715412,
#        0.03284029, 0.03236433, 0.07850579, 0.01290428, 0.08436641,
#        0.08801102, 0.01405291, 0.0486075 , 0.08774333, 0.03743371])

# %%
data.head()
# Out:
# Attributes   Adj Close                                                      \
# Symbols         ITC.NS AMBUJACEM.NS ADANIPORTS.NS     SBIN.NS        LT.NS
# Date
# 2019-10-22  214.867920   175.591476    410.412537  263.906891  1350.745117
# 2019-10-23  216.723938   176.398178    386.368195  268.736237  1340.679443
# 2019-10-24  214.997421   177.160065    389.343201  256.101868  1341.100830
# 2019-10-25  213.832001   176.980789    389.148132  274.687531  1334.312134
# 2019-10-27  216.162827   177.070435    389.977264  274.931458  1343.113892
#
# Attributes                                                                ...  \
# Symbols    PATANJALI.NS     IRB.NS   FORTIS.NS LINDEINDIA.NS  ESCORTS.NS  ...
# Date                                                                      ...
# 2019-10-22   363.765686  68.061974  138.399994    513.481201  639.276855  ...
# 2019-10-23   358.782593  77.260826  137.199997    523.513916  649.532593  ...
# ...

# %%
# data.keys()

# %%
data_1=data['Close']

# %%
data_1
# Out:
# Symbols         ITC.NS  AMBUJACEM.NS  ADANIPORTS.NS     SBIN.NS        LT.NS  \
# Date
# 2019-10-22  248.899994    195.899994     420.750000  270.500000  1442.550049
# 2019-10-23  251.050003    196.800003     396.100006  275.450012  1431.800049
# 2019-10-24  249.050003    197.649994     399.149994  262.500000  1432.250000
# 2019-10-25  247.699997    197.449997     398.950012  281.549988  1425.000000
# 2019-10-27  250.399994    197.550003     399.799988  281.799988  1434.400024
# ...                ...           ...            ...         ...          ...
# 2022-10-17  332.250000    520.549988     786.200012  543.650024  1883.199951
# 2022-10-18  340.299988    507.850006     809.950012  562.450012  1918.099976
# 2022-10-19  346.350006    510.700012     805.049988  553.400024  1904.900024
# 2022-10-20  349.700012    517.700012     820.049988  555.400024  1904.150024
# 2022-10-21  345.600006    512.599976     801.650024  560.849976  1876.750000
#
# ...

# %%
data_1/data_1.iloc[0]
# Out:
# Symbols       ITC.NS  AMBUJACEM.NS  ADANIPORTS.NS   SBIN.NS     LT.NS  \
# Date
# 2019-10-22  1.000000      1.000000       1.000000  1.000000  1.000000
# 2019-10-23  1.008638      1.004594       0.941414  1.018299  0.992548
# 2019-10-24  1.000603      1.008933       0.948663  0.970425  0.992860
# 2019-10-25  0.995179      1.007912       0.948188  1.040850  0.987834
# 2019-10-27  1.006027      1.008423       0.950208  1.041774  0.994350
# ...              ...           ...            ...       ...       ...
# 2022-10-17  1.334873      2.657223       1.868568  2.009797  1.305466
# 2022-10-18  1.367216      2.592394       1.925015  2.079298  1.329659
# 2022-10-19  1.391523      2.606942       1.913369  2.045841  1.320509
# 2022-10-20  1.404982      2.642675       1.949020  2.053235  1.319989
# 2022-10-21  1.388510      2.616641       1.905288  2.073383  1.300995
#
# Symbols     PATANJALI.NS    IRB.NS  FORTIS.NS  LINDEINDIA.NS  ESCORTS.NS  \
# Date
# ...

# %%
daily_return = (data_1/data_1.shift())-1
daily_return.dropna(inplace=True)
fig, ax = plt.subplots(figsize=(15,8))
for i in daily_simple_return.columns.values :
    ax.plot(daily_simple_return[i], lw =2 ,label = i)


ax.legend( loc = 'upper right' , fontsize =10)
ax.set_title('Volatility in Daily simple returns ')
ax.set_xlabel('Date')
ax.set_ylabel('Daily simple returns')
plt.show(fig)

# %%
print('Average Daily returns(%) of stocks in your portfolio')
Avg_daily = daily_return.mean()
print(Avg_daily*100)
# Out:
# Average Daily returns(%) of stocks in your portfolio
# Symbols
# ITC.NS           0.175598
# AMBUJACEM.NS     0.148263
# ADANIPORTS.NS    0.060536
# SBIN.NS          0.094979
# LT.NS            0.080232
# PATANJALI.NS     0.126212
# IRB.NS           0.171961
# FORTIS.NS        0.060907
# LINDEINDIA.NS    0.213634
# ESCORTS.NS       0.178834
# ZEEL.NS          0.130656
# CRISIL.NS        0.054625
# KOTAKBANK.NS     0.043534
# AEGISCHEM.NS    -0.004057
# HFCL.NS          0.018878
# SUNPHARMA.NS     0.124442
# TATACOMM.NS     -0.012148
# RELIANCE.NS      0.057295
# IPL.NS          -0.045595
# CUMMINSIND.NS    0.113614
# dtype: float64

# %%
high_low = data['High']- data ['Low']
high_closePrevious = np.abs(data['High'] - data ['Close'].shift())
low_closePrevious = np.abs(data['Low'] - data ['Close'].shift())

# %%
high_low
# Out:
# Symbols        ITC.NS  AMBUJACEM.NS  ADANIPORTS.NS    SBIN.NS      LT.NS  \
# Date
# 2019-10-22   6.150009     12.899994      11.750000   6.500000  28.650024
# 2019-10-23   2.899994      4.699997      24.000000   9.149994  30.300049
# 2019-10-24   6.050003      4.949997       8.100006  29.000000  40.650024
# 2019-10-25  10.200012      3.800003       6.100006  20.600006  21.599976
# 2019-10-27   1.400009      1.899994       3.700012   4.700012  10.099976
# ...               ...           ...            ...        ...        ...
# 2022-10-17   5.149994     25.250000      18.299988  20.500000  35.599976
# 2022-10-18   7.450012     18.150024      24.500000  16.750000  38.099976
# 2022-10-19   7.650024     12.299988      22.299988  11.900024  45.349976
# 2022-10-20   6.150024     12.000000      27.200012  11.500000  31.500000
# 2022-10-21   8.700012     19.100037      24.799988   8.549988  57.900024
#
# Symbols     PATANJALI.NS     IRB.NS  FORTIS.NS  LINDEINDIA.NS  ESCORTS.NS  \
# Date
# ...

# %%
high_closePrevious
# Out:
# Symbols       ITC.NS  AMBUJACEM.NS  ADANIPORTS.NS    SBIN.NS      LT.NS  \
# Date
# 2019-10-22       NaN           NaN            NaN        NaN        NaN
# 2019-10-23  3.050003      1.900009       1.750000   7.299988   6.349976
# 2019-10-24  2.949997      2.649994       5.350006   2.199982  35.199951
# 2019-10-25  8.150009      1.450012       3.800018  21.649994   9.449951
# 2019-10-27  3.400009      1.449997       3.299988   3.400024  13.949951
# ...              ...           ...            ...        ...        ...
# 2022-10-17  2.649994     20.850006       9.850037  17.500000   2.400024
# 2022-10-18  8.750000      3.650024      28.799988  19.849976  48.000000
# 2022-10-19  7.150024     11.149994      13.500000   1.000000  28.900024
# 2022-10-20  4.600006      8.299988      17.200012   3.399963  12.900024
# 2022-10-21  3.500000      5.200012       4.150024  10.399963  20.849976
#
# Symbols     PATANJALI.NS     IRB.NS  FORTIS.NS  LINDEINDIA.NS  ESCORTS.NS  \
# Date
# ...

# %%
low_closePrevious
# Out:
# Symbols       ITC.NS  AMBUJACEM.NS  ADANIPORTS.NS    SBIN.NS      LT.NS  \
# Date
# 2019-10-22       NaN           NaN            NaN        NaN        NaN
# 2019-10-23  0.150009      2.799988      25.750000   1.850006  23.950073
# 2019-10-24  3.100006      2.300003       2.750000  26.800018   5.450073
# 2019-10-25  2.050003      2.349991       2.299988   1.049988  12.150024
# 2019-10-27  2.000000      0.449997       0.400024   1.299988   3.849976
# ...              ...           ...            ...        ...        ...
# 2022-10-17  2.500000      4.399994       8.449951   3.000000  33.199951
# 2022-10-18  1.299988     14.500000       4.299988   3.099976   9.900024
# 2022-10-19  0.500000      1.149994       8.799988  10.900024  16.449951
# 2022-10-20  1.550018      3.700012      10.000000   8.100037  18.599976
# 2022-10-21  5.200012     13.900024      20.649963   1.849976  37.050049
#
# Symbols     PATANJALI.NS     IRB.NS  FORTIS.NS  LINDEINDIA.NS  ESCORTS.NS  \
# Date
# ...

# %%
df1 = pd.DataFrame(pd.concat([high_low,high_closePrevious,low_closePrevious],axis=1) )

# %%
df1
# Out:
# Symbols        ITC.NS  AMBUJACEM.NS  ADANIPORTS.NS    SBIN.NS      LT.NS  \
# Date
# 2019-10-22   6.150009     12.899994      11.750000   6.500000  28.650024
# 2019-10-23   2.899994      4.699997      24.000000   9.149994  30.300049
# 2019-10-24   6.050003      4.949997       8.100006  29.000000  40.650024
# 2019-10-25  10.200012      3.800003       6.100006  20.600006  21.599976
# 2019-10-27   1.400009      1.899994       3.700012   4.700012  10.099976
# ...               ...           ...            ...        ...        ...
# 2022-10-17   5.149994     25.250000      18.299988  20.500000  35.599976
# 2022-10-18   7.450012     18.150024      24.500000  16.750000  38.099976
# 2022-10-19   7.650024     12.299988      22.299988  11.900024  45.349976
# 2022-10-20   6.150024     12.000000      27.200012  11.500000  31.500000
# 2022-10-21   8.700012     19.100037      24.799988   8.549988  57.900024
#
# Symbols     PATANJALI.NS     IRB.NS  FORTIS.NS  LINDEINDIA.NS  ESCORTS.NS  \
# Date
# ...

# %%
true_range = pd.DataFrame()

# %%
for i in tickers_1:
    true_range[i] = np.max(df1[i],axis=1)

# %%
true_range
# Out:
#                ITC.NS  AMBUJACEM.NS  ADANIPORTS.NS    SBIN.NS      LT.NS  \
# Date
# 2019-10-22   6.150009     12.899994      11.750000   6.500000  28.650024
# 2019-10-23   3.050003      4.699997      25.750000   9.149994  30.300049
# 2019-10-24   6.050003      4.949997       8.100006  29.000000  40.650024
# 2019-10-25  10.200012      3.800003       6.100006  21.649994  21.599976
# 2019-10-27   3.400009      1.899994       3.700012   4.700012  13.949951
# ...               ...           ...            ...        ...        ...
# 2022-10-17   5.149994     25.250000      18.299988  20.500000  35.599976
# 2022-10-18   8.750000     18.150024      28.799988  19.849976  48.000000
# 2022-10-19   7.650024     12.299988      22.299988  11.900024  45.349976
# 2022-10-20   6.150024     12.000000      27.200012  11.500000  31.500000
# 2022-10-21   8.700012     19.100037      24.799988  10.399963  57.900024
#
#             PATANJALI.NS     IRB.NS  FORTIS.NS  LINDEINDIA.NS  ESCORTS.NS  \
# Date
# ...

# %%
average_true_range = true_range.rolling(14).mean()

# %%
# for i in tickers:
fig, ax = plt.subplots(figsize=(30,20))
average_true_range.plot(ax=ax)
ax2 = data_1.plot(ax=ax, secondary_y=True, alpha=.3)
ax.set_ylabel("ATR")
ax2.set_ylabel("Price")
# Out:
# Text(0, 0.5, 'Price')

# %%
daily_simple_return.plot(kind = "box",figsize = (40,15), title = "Risk Box Plot")
# Out:
# <AxesSubplot:title={'center':'Risk Box Plot'}>

# %%
# Quartile range higher , higher the volatility , more the risk 
# more Positive outliers, more is the return

# %%
df2 = data['Adj Close']

# %%
portfolio=[0.1,0.088,0.085,0.074,0.073,0.065,0.052,0.05,0.05,0.05,0.045,0.042,0.04,0.038,0.037,0.034,0.025,0.022,0.02,0.01]

# %%
np.sum(portfolio)
# Out:
# 1.0

# %%
df2/df2.shift()
# Out:
# Symbols       ITC.NS  AMBUJACEM.NS  ADANIPORTS.NS   SBIN.NS     LT.NS  \
# Date
# 2019-10-22       NaN           NaN            NaN       NaN       NaN
# 2019-10-23  1.008638      1.004594       0.941414  1.018299  0.992548
# 2019-10-24  0.992034      1.004319       1.007700  0.952986  1.000314
# 2019-10-25  0.994579      0.998988       0.999499  1.072571  0.994938
# 2019-10-27  1.010900      1.000507       1.002131  1.000888  1.006596
# ...              ...           ...            ...       ...       ...
# 2022-10-17  1.000452      1.037262       1.007820  1.031203  0.985143
# 2022-10-18  1.024229      0.975603       1.030209  1.034581  1.018532
# 2022-10-19  1.017778      1.005612       0.993950  0.983910  0.993118
# 2022-10-20  1.009672      1.013707       1.018632  1.003614  0.999606
# 2022-10-21  0.988276      0.990149       0.977562  1.009813  0.985610
#
# Symbols     PATANJALI.NS    IRB.NS  FORTIS.NS  LINDEINDIA.NS  ESCORTS.NS  \
# Date
# ...

# %%
log_returns = np.log(df2/df2.shift())

# %%
log_returns
# Out:
# Symbols       ITC.NS  AMBUJACEM.NS  ADANIPORTS.NS   SBIN.NS     LT.NS  \
# Date
# 2019-10-22       NaN           NaN            NaN       NaN       NaN
# 2019-10-23  0.008601      0.004584      -0.060372  0.018134 -0.007480
# 2019-10-24 -0.007998      0.004310       0.007670 -0.048155  0.000314
# 2019-10-25 -0.005435     -0.001012      -0.000501  0.070059 -0.005075
# 2019-10-27  0.010841      0.000506       0.002128  0.000888  0.006575
# ...              ...           ...            ...       ...       ...
# 2022-10-17  0.000452      0.036585       0.007789  0.030726 -0.014968
# 2022-10-18  0.023940     -0.024700       0.029761  0.033997  0.018363
# 2022-10-19  0.017622      0.005596      -0.006068 -0.016221 -0.006906
# 2022-10-20  0.009626      0.013614       0.018461  0.003608 -0.000394
# 2022-10-21 -0.011794     -0.009900      -0.022693  0.009765 -0.014494
#
# Symbols     PATANJALI.NS    IRB.NS  FORTIS.NS  LINDEINDIA.NS  ESCORTS.NS  \
# Date
# ...

# %%
log_return = np.sum(np.log(df2/df2.shift())*portfolio,axis=1)

# %%
fig, ax = plt.subplots(figsize=(10,8))
log_return.hist(bins=50, ax=ax)
# Out:
# <AxesSubplot:>

# %%
log_return.std()
# Out:
# 0.01578376974288794

# %%
log_return.mean()
# Out:
# 0.001082791194918417

# %%
np.exp(log_return.mean())
# Out:
# 1.0010833776249457

# %%
sharpe_ratio = (log_return.mean()-(0.12/364))/log_return.std()
sharpe_ratio
# Out:
# 0.04771489178543284

# %%
asr = sharpe_ratio*(750**.5)

# %%
asr
# Out:
# 1.3067261279899758

# %%
information_ratio = (log_return.mean()-(0.112/252))/log_return.std()
information_ratio
# Out:
# 0.04044323763412775

# %%
annual_infomation_ratio = information_ratio*(252**.5)
annual_infomation_ratio
# Out:
# 0.6420164939651417

# %%
## Montecarlo simulation

# %%
weights = np.random.random(20)
weights /= weights.sum()
weights
# Out:
# array([0.05068879, 0.0649011 , 0.03357568, 0.06313386, 0.0706592 ,
#        0.02953429, 0.05670961, 0.04516839, 0.02090844, 0.07036985,
#        0.04011151, 0.01619012, 0.02268169, 0.05103583, 0.08859002,
#        0.06060499, 0.08628548, 0.093936  , 0.00051627, 0.03439886])

# %%
weights.sum()
# Out:
# 1.0000000000000002

# %%
exp_return = np.sum(log_returns.mean()*weights)*255

# %%
exp_return
# Out:
# 0.29662829937897406

# %%
exp_volume = np.sqrt(np.dot(weights.T, np.dot(log_returns.cov()*255, weights)))

# %%
sharpe_ratio1 = exp_return / exp_volume

# %%
sharpe_ratio1
# Out:
# 1.2334336035636702

# %%
n = 500

weights1 = np.zeros((n, 20))
exp_returns = np.zeros(n)
exp_volumes = np.zeros(n)
sharpe_ratios = np.zeros(n)
information_ratios = np.zeros(n)

for i in range(n):
    weight = np.random.random(20)
    weight /= weight.sum()
    weights1[i] = weight
    
    exp_returns[i] = np.sum(log_returns.mean()*weight)*252
    exp_volumes[i] = np.sqrt(np.dot(weight.T, np.dot(log_returns.cov()*252, weight)))
    sharpe_ratios[i] = (exp_returns[i]-(0.0702/364))/exp_volumes[i]
    information_ratios[i] = (exp_returns[i]-(0.112/252))/exp_volumes[i]

# %%
sharpe_ratios.max()
# Out:
# 1.3727131803040091

# %%
sharpe_ratios.argmax()
# Out:
# 41

# %%
information_ratios.max()
# Out:
# 1.3716376255125973

# %%
information_ratios.argmax()
# Out:
# 41

# %%
weights1[41]
# Out:
# array([0.05683918, 0.07892118, 0.03110626, 0.00986392, 0.03990734,
#        0.02794654, 0.06375039, 0.03331678, 0.10924578, 0.03457799,
#        0.00915561, 0.06578935, 0.02097847, 0.09537   , 0.08553998,
#        0.05433486, 0.1018588 , 0.00052896, 0.03963816, 0.04133045])

# %%
fig, ax = plt.subplots()
ax.scatter(exp_volumes, exp_returns, c=sharpe_ratios)
ax.scatter(exp_volumes[sharpe_ratios.argmax()], exp_returns[sharpe_ratios.argmax()], c='r')
ax.set_xlabel('Expected Volatility')
ax.set_ylabel('Expected Return')
# Out:
# Text(0, 0.5, 'Expected Return')

# %%
# Red dot shows the highest Sharpe ratio

# %%
fig, ax = plt.subplots()
ax.scatter(exp_volumes, exp_returns, c=sharpe_ratios)
ax.scatter(exp_volumes[sharpe_ratios.argmax()], exp_returns[information_ratios.argmax()], c='r')
ax.set_xlabel('Expected Volatility')
ax.set_ylabel('Expected Return')
# Out:
# Text(0, 0.5, 'Expected Return')

# %%
##correlation

# %%
log_returns.corr()
# Out:
# Symbols          ITC.NS  AMBUJACEM.NS  ADANIPORTS.NS   SBIN.NS     LT.NS  \
# Symbols
# ITC.NS         1.000000      0.321563       0.368823  0.462528  0.407123
# AMBUJACEM.NS   0.321563      1.000000       0.411820  0.449050  0.434449
# ADANIPORTS.NS  0.368823      0.411820       1.000000  0.462974  0.515890
# SBIN.NS        0.462528      0.449050       0.462974  1.000000  0.573190
# LT.NS          0.407123      0.434449       0.515890  0.573190  1.000000
# PATANJALI.NS   0.041061      0.029372       0.062469  0.047667  0.038883
# IRB.NS         0.268935      0.221880       0.308396  0.362455  0.386344
# FORTIS.NS      0.205429      0.254834       0.282845  0.220707  0.252402
# LINDEINDIA.NS  0.226011      0.241392       0.312565  0.320415  0.287459
# ESCORTS.NS     0.324935      0.346172       0.396969  0.351515  0.374388
# ZEEL.NS        0.248075      0.263913       0.354656  0.341477  0.351118
# CRISIL.NS      0.119287      0.238558       0.211339  0.230499  0.228810
# ...

# %%
import seaborn as sns

# %%
fig1 = plt.figure(figsize=(20,20))
dataplot = sns.heatmap(log_returns.corr(),cmap='YlGnBu',annot= True)

plt.show(fig1)

# %%
N_INDEX = pdr.get_data_yahoo("^NSEI", start)

# %%
log_returns['N_INDEX'] = np.log(N_INDEX['Adj Close']/N_INDEX['Adj Close'].shift())

# %%
log_returns.corr()
# Out:
# Symbols          ITC.NS  AMBUJACEM.NS  ADANIPORTS.NS   SBIN.NS     LT.NS  \
# Symbols
# ITC.NS         1.000000      0.321563       0.368823  0.462528  0.407123
# AMBUJACEM.NS   0.321563      1.000000       0.411820  0.449050  0.434449
# ADANIPORTS.NS  0.368823      0.411820       1.000000  0.462974  0.515890
# SBIN.NS        0.462528      0.449050       0.462974  1.000000  0.573190
# LT.NS          0.407123      0.434449       0.515890  0.573190  1.000000
# PATANJALI.NS   0.041061      0.029372       0.062469  0.047667  0.038883
# IRB.NS         0.268935      0.221880       0.308396  0.362455  0.386344
# FORTIS.NS      0.205429      0.254834       0.282845  0.220707  0.252402
# LINDEINDIA.NS  0.226011      0.241392       0.312565  0.320415  0.287459
# ESCORTS.NS     0.324935      0.346172       0.396969  0.351515  0.374388
# ZEEL.NS        0.248075      0.263913       0.354656  0.341477  0.351118
# CRISIL.NS      0.119287      0.238558       0.211339  0.230499  0.228810
# ...

# %%
fig2 = plt.figure(figsize=(22,22))
dataplot = sns.heatmap(log_returns.corr(),cmap='YlGnBu',annot= True)

plt.show(fig2)

# %%
from sklearn.linear_model import LinearRegression

# %%
tickers_n = ['ITC.NS', 'AMBUJACEM.NS', 'ADANIPORTS.NS', 'SBIN.NS','LT.NS','PATANJALI.NS','IRB.NS','FORTIS.NS','LINDEINDIA.NS','ESCORTS.NS','ZEEL.NS','CRISIL.NS','KOTAKBANK.NS','AEGISCHEM.NS','HFCL.NS','SUNPHARMA.NS','TATACOMM.NS','RELIANCE.NS','IPL.NS','CUMMINSIND.NS','^NSEI']

# %%
start = dt.datetime(2019, 10, 21)
data_n = pdr.get_data_yahoo(tickers_n, start)

# %%
data_n1 = data_n['Adj Close']

# %%
log_rtns_n = np.log(data_n1/data_n1.shift())

# %%
log_rtns_n
# Out:
# Symbols       ITC.NS  AMBUJACEM.NS  ADANIPORTS.NS   SBIN.NS     LT.NS  \
# Date
# 2019-10-22       NaN           NaN            NaN       NaN       NaN
# 2019-10-23  0.008601      0.004584      -0.060372  0.018134 -0.007480
# 2019-10-24 -0.007998      0.004310       0.007671 -0.048155  0.000314
# 2019-10-25 -0.005435     -0.001012      -0.000501  0.070059 -0.005075
# 2019-10-27  0.010841      0.000506       0.002128  0.000888  0.006575
# ...              ...           ...            ...       ...       ...
# 2022-10-17  0.000452      0.036585       0.007789  0.030726 -0.014968
# 2022-10-18  0.023940     -0.024700       0.029761  0.033997  0.018363
# 2022-10-19  0.017622      0.005596      -0.006068 -0.016221 -0.006906
# 2022-10-20  0.009626      0.013614       0.018461  0.003608 -0.000394
# 2022-10-21 -0.011794     -0.009900      -0.022693  0.009765 -0.014494
#
# Symbols     PATANJALI.NS    IRB.NS  FORTIS.NS  LINDEINDIA.NS  ESCORTS.NS  ...  \
# ...

# %%
cov = log_rtns_n.cov()

# %%
var = log_rtns_n['^NSEI'].var()

# %%
var
# Out:
# 0.00020555245662566373

# %%
cov.loc['ITC.NS', '^NSEI']/var
# Out:
# 0.7055672457389617

# %%
cov.loc['^NSEI']/var
# Out:
# Symbols
# ITC.NS           0.705567
# AMBUJACEM.NS     0.784567
# ADANIPORTS.NS    1.086071
# SBIN.NS          1.214100
# LT.NS            1.016287
# PATANJALI.NS     0.474565
# IRB.NS           1.037539
# FORTIS.NS        0.599145
# LINDEINDIA.NS    0.805038
# ESCORTS.NS       1.024589
# ZEEL.NS          1.150872
# CRISIL.NS        0.494868
# KOTAKBANK.NS     1.075110
# AEGISCHEM.NS     0.806351
# HFCL.NS          1.048738
# SUNPHARMA.NS     0.659192
# TATACOMM.NS      0.514119
# RELIANCE.NS      1.077940
# IPL.NS           0.582606
# CUMMINSIND.NS    0.565848
# ^CRSLDX          0.950872
# ^NSEI            1.000000
# Name: ^NSEI, dtype: float64

# %%
beta_itc=cov.loc['ITC.NS', '^NSEI']/var

# %%
risk_free_return=0.0702
market_return=0.112
expected_return = risk_free_return + beta_itc*(market_return - risk_free_return)

# %%
expected_return
# Out:
# 0.0996927108718886

# %%
beta = cov.loc['^NSEI']/var

# %%
beta.mean()
# Out:
# 0.8488173920954861

# %%
## CAPM

# %%
expected_return = risk_free_return + beta*(market_return - risk_free_return)

# %%
expected_return
# Out:
# Symbols
# ITC.NS           0.091009
# AMBUJACEM.NS     0.095930
# ADANIPORTS.NS    0.119505
# SBIN.NS          0.131815
# LT.NS            0.113373
# PATANJALI.NS     0.079614
# IRB.NS           0.115197
# FORTIS.NS        0.085205
# LINDEINDIA.NS    0.097290
# ESCORTS.NS       0.114081
# ZEEL.NS          0.125564
# CRISIL.NS        0.080437
# KOTAKBANK.NS     0.118515
# AEGISCHEM.NS     0.097378
# HFCL.NS          0.116174
# SUNPHARMA.NS     0.088364
# TATACOMM.NS      0.081248
# RELIANCE.NS      0.118770
# IPL.NS           0.084388
# CUMMINSIND.NS    0.083584
# ^CRSLDX          0.107994
# ^NSEI            0.112000
# Name: ^NSEI, dtype: float64

# %%
expected_return.mean()
# Out:
# 0.1026106429178588

# %%
## Jensen's Alpha
## Average_portfolio_return-CAPM(expected_return)
Jensen= exp_return-expected_return.mean()
Jensen
# Out:
# 0.18823771323678856

# %%
## Treynor's Ratio
## (Average_portfolio_return-risk_free_rate)/beta
treynor= (exp_return-risk_free_return)/beta.mean()
treynor
# Out:
# 0.2599479678543462

# %%
returns = data_1.pct_change()
mean_returns = returns.mean()
cov_matrix = returns.cov()
num_portfolios = 10000
risk_free_rate = 0.0702

# %%
def portfolio_annualised_performance(weights, mean_returns, cov_matrix):
    returns = np.sum(mean_returns*weights ) *252
    std = np.sqrt(np.dot(weights.T, np.dot(cov_matrix, weights))) * np.sqrt(252)
    return std, returns

# %%
def random_portfolios(num_portfolios, mean_returns, cov_matrix, risk_free_rate):
    results = np.zeros((3,num_portfolios))
    weights_record = []
    for i in range(num_portfolios):
        weights = np.random.random(20)
        weights /= np.sum(weights)
        weights_record.append(weights)
        portfolio_std_dev, portfolio_return = portfolio_annualised_performance(weights, mean_returns, cov_matrix)
        results[0,i] = portfolio_std_dev
        results[1,i] = portfolio_return
        results[2,i] = (portfolio_return - risk_free_rate) / portfolio_std_dev
    return results, weights_record

# %%
def display_simulated_ef_with_random(mean_returns, cov_matrix, num_portfolios, risk_free_rate):
    results, weights = random_portfolios(num_portfolios,mean_returns, cov_matrix, risk_free_rate)
    
    max_sharpe_idx = np.argmax(results[2])
    sdp, rp = results[0,max_sharpe_idx], results[1,max_sharpe_idx]
    max_sharpe_allocation = pd.DataFrame(weights[max_sharpe_idx],index=data_1.columns,columns=['allocation'])
    max_sharpe_allocation.allocation = [round(i*100,2)for i in max_sharpe_allocation.allocation]
    max_sharpe_allocation = max_sharpe_allocation.T
    
    min_vol_idx = np.argmin(results[0])
    sdp_min, rp_min = results[0,min_vol_idx], results[1,min_vol_idx]
    min_vol_allocation = pd.DataFrame(weights[min_vol_idx],index=data_1.columns,columns=['allocation'])
    min_vol_allocation.allocation = [round(i*100,2)for i in min_vol_allocation.allocation]
    min_vol_allocation = min_vol_allocation.T
    
    print ("-"*80)
    print ("Maximum Sharpe Ratio Portfolio Allocation\n")
    print ("Annualised Return:", round(rp,2))
    print ("Annualised Volatility:", round(sdp,2))
    print ("\n")
    print (max_sharpe_allocation)
    print ("-"*80)
    print ("Minimum Volatility Portfolio Allocation\n")
    print ("Annualised Return:", round(rp_min,2))
    print ("Annualised Volatility:", round(sdp_min,2))
    print ("\n")
    print (min_vol_allocation)
    
    plt.figure(figsize=(10, 7))
    plt.scatter(results[0,:],results[1,:],c=results[2,:],cmap='YlGnBu', marker='o', s=10, alpha=0.3)
    plt.colorbar()
    plt.scatter(sdp,rp,marker='*',color='r',s=500, label='Maximum Sharpe ratio')
    plt.scatter(sdp_min,rp_min,marker='*',color='g',s=500, label='Minimum volatility')
    plt.title('Simulated Portfolio Optimization based on Efficient Frontier')
    plt.xlabel('annualised volatility')
    plt.ylabel('annualised returns')
    plt.legend(labelspacing=0.8)

# %%
display_simulated_ef_with_random(mean_returns, cov_matrix, num_portfolios, risk_free_rate)
# Out:
# --------------------------------------------------------------------------------
# Maximum Sharpe Ratio Portfolio Allocation
#
# Annualised Return: 0.5
# Annualised Volatility: 0.23
#
#
# Symbols     ITC.NS  AMBUJACEM.NS  ADANIPORTS.NS  SBIN.NS  LT.NS  PATANJALI.NS  \
# allocation    0.59          4.97            0.5     3.01   2.87         12.25
#
# Symbols     IRB.NS  FORTIS.NS  LINDEINDIA.NS  ESCORTS.NS  ZEEL.NS  CRISIL.NS  \
# allocation    4.85      10.41           7.55        9.59     3.14       3.36
#
# Symbols     KOTAKBANK.NS  AEGISCHEM.NS  HFCL.NS  SUNPHARMA.NS  TATACOMM.NS  \
# allocation          1.84          4.35     4.79          0.19        10.33
#
# Symbols     RELIANCE.NS  IPL.NS  CUMMINSIND.NS
# allocation         4.78    3.44           7.19
# --------------------------------------------------------------------------------
# Minimum Volatility Portfolio Allocation
#
# Annualised Return: 0.36
# Annualised Volatility: 0.2
#
#
# ...

# %%
def neg_sharpe_ratio(weights, mean_returns, cov_matrix, risk_free_rate):
    p_var, p_ret = portfolio_annualised_performance(weights, mean_returns, cov_matrix)
    return -(p_ret - risk_free_rate) / p_var

def max_sharpe_ratio(mean_returns, cov_matrix, risk_free_rate):
    num_assets = len(mean_returns)
    args = (mean_returns, cov_matrix, risk_free_rate)
    constraints = ({'type': 'eq', 'fun': lambda x: np.sum(x) - 1})
    bound = (0.0,1.0)
    bounds = tuple(bound for asset in range(num_assets))
    result = sco.minimize(neg_sharpe_ratio, num_assets*[1./num_assets,], args=args,
                        method='SLSQP', bounds=bounds, constraints=constraints)
    return result

# %%
def portfolio_volatility(weights, mean_returns, cov_matrix):
    return portfolio_annualised_performance(weights, mean_returns, cov_matrix)[0]

def min_variance(mean_returns, cov_matrix):
    num_assets = len(mean_returns)
    args = (mean_returns, cov_matrix)
    constraints = ({'type': 'eq', 'fun': lambda x: np.sum(x) - 1})
    bound = (0.0,1.0)
    bounds = tuple(bound for asset in range(num_assets))

    result = sco.minimize(portfolio_volatility, num_assets*[1./num_assets,], args=args,
                        method='SLSQP', bounds=bounds, constraints=constraints)

    return result

# %%
def efficient_return(mean_returns, cov_matrix, target):
    num_assets = len(mean_returns)
    args = (mean_returns, cov_matrix)

    def portfolio_return(weights):
        return portfolio_annualised_performance(weights, mean_returns, cov_matrix)[1]

    constraints = ({'type': 'eq', 'fun': lambda x: portfolio_return(x) - target},
                   {'type': 'eq', 'fun': lambda x: np.sum(x) - 1})
    bounds = tuple((0,1) for asset in range(num_assets))
    result = sco.minimize(portfolio_volatility, num_assets*[1./num_assets,], args=args, method='SLSQP', bounds=bounds, constraints=constraints)
    return result


def efficient_frontier(mean_returns, cov_matrix, returns_range):
    efficients = []
    for ret in returns_range:
        efficients.append(efficient_return(mean_returns, cov_matrix, ret))
    return efficients

# %%
def display_calculated_ef_with_random(mean_returns, cov_matrix, num_portfolios, risk_free_rate):
    results, _ = random_portfolios(num_portfolios,mean_returns, cov_matrix, risk_free_rate)
    
    max_sharpe = max_sharpe_ratio(mean_returns, cov_matrix, risk_free_rate)
    sdp, rp = portfolio_annualised_performance(max_sharpe['x'], mean_returns, cov_matrix)
    max_sharpe_allocation = pd.DataFrame(max_sharpe.x,index=table.columns,columns=['allocation'])
    max_sharpe_allocation.allocation = [round(i*100,2)for i in max_sharpe_allocation.allocation]
    max_sharpe_allocation = max_sharpe_allocation.T
    max_sharpe_allocation

    min_vol = min_variance(mean_returns, cov_matrix)
    sdp_min, rp_min = portfolio_annualised_performance(min_vol['x'], mean_returns, cov_matrix)
    min_vol_allocation = pd.DataFrame(min_vol.x,index=table.columns,columns=['allocation'])
    min_vol_allocation.allocation = [round(i*100,2)for i in min_vol_allocation.allocation]
    min_vol_allocation = min_vol_allocation.T
    
    print ("-"*80)
    print ("Maximum Sharpe Ratio Portfolio Allocation\n")
    print ("Annualised Return:", round(rp,2))
    print ("Annualised Volatility:", round(sdp,2))
    print ("\n")
    print (max_sharpe_allocation)
    print ("-"*80)
    print ("Minimum Volatility Portfolio Allocation\n")
    print ("Annualised Return:", round(rp_min,2))
    print ("Annualised Volatility:", round(sdp_min,2))
    print ("\n")
    print (min_vol_allocation)
    
    plt.figure(figsize=(10, 7))
    plt.scatter(results[0,:],results[1,:],c=results[2,:],cmap='YlGnBu', marker='o', s=10, alpha=0.3)
    plt.colorbar()
    plt.scatter(sdp,rp,marker='*',color='r',s=500, label='Maximum Sharpe ratio')
    plt.scatter(sdp_min,rp_min,marker='*',color='g',s=500, label='Minimum volatility')

    target = np.linspace(rp_min, 0.32, 50)
    efficient_portfolios = efficient_frontier(mean_returns, cov_matrix, target)
    plt.plot([p['fun'] for p in efficient_portfolios], target, linestyle='-.', color='black', label='efficient frontier')
    plt.title('Calculated Portfolio Optimization based on Efficient Frontier')
    plt.xlabel('annualised volatility')
    plt.ylabel('annualised returns')
    plt.legend(labelspacing=0.8)

# %%
display_calculated_ef_with_random(mean_returns, cov_matrix, num_portfolios, risk_free_rate)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-240-6ad8cc3d9d0f> in <module>
# ----> 1 display_calculated_ef_with_random(mean_returns, cov_matrix, num_portfolios, risk_free_rate)
#
# <ipython-input-239-3ab517416822> in display_calculated_ef_with_random(mean_returns, cov_matrix, num_portfolios, risk_free_rate)
#       2     results, _ = random_portfolios(num_portfolios,mean_returns, cov_matrix, risk_free_rate)
#       3
# ----> 4     max_sharpe = max_sharpe_ratio(mean_returns, cov_matrix, risk_free_rate)
#       5     sdp, rp = portfolio_annualised_performance(max_sharpe['x'], mean_returns, cov_matrix)
#       6     max_sharpe_allocation = pd.DataFrame(max_sharpe.x,index=table.columns,columns=['allocation'])
#
# <ipython-input-232-a0cf177370eb> in max_sharpe_ratio(mean_returns, cov_matrix, risk_free_rate)
#       9     bound = (0.0,1.0)
# ...

# %%
def display_ef_with_selected(mean_returns, cov_matrix, risk_free_rate):
    max_sharpe = max_sharpe_ratio(mean_returns, cov_matrix, risk_free_rate)
    sdp, rp = portfolio_annualised_performance(max_sharpe['x'], mean_returns, cov_matrix)
    max_sharpe_allocation = pd.DataFrame(max_sharpe.x,index=data_1.columns,columns=['allocation'])
    max_sharpe_allocation.allocation = [round(i*100,2)for i in max_sharpe_allocation.allocation]
    max_sharpe_allocation = max_sharpe_allocation.T

    min_vol = min_variance(mean_returns, cov_matrix)
    sdp_min, rp_min = portfolio_annualised_performance(min_vol['x'], mean_returns, cov_matrix)
    min_vol_allocation = pd.DataFrame(min_vol.x,index=data_1.columns,columns=['allocation'])
    min_vol_allocation.allocation = [round(i*100,2)for i in min_vol_allocation.allocation]
    min_vol_allocation = min_vol_allocation.T
    
    an_vol = np.std(returns) * np.sqrt(252)
    an_rt = mean_returns * 252
    
    print ("-"*80)
    print ("Maximum Sharpe Ratio Portfolio Allocation\n")
    print ("Annualised Return:", round(rp,2))
    print ("Annualised Volatility:", round(sdp,2))
    print ("\n")
    print (max_sharpe_allocation)
    print ("-"*80)
    print ("Minimum Volatility Portfolio Allocation\n")
    print ("Annualised Return:", round(rp_min,2))
    print ("Annualised Volatility:", round(sdp_min,2))
    print ("\n")
    print (min_vol_allocation)
    print ("-"*80)
    print ("Individual Stock Returns and Volatility\n")
    for i, txt in enumerate(data_1.columns):
        print (txt,":","annuaised return",round(an_rt[i],2),", annualised volatility:",round(an_vol[i],2))
    print ("-"*80)
    
    fig, ax = plt.subplots(figsize=(10, 7))
    ax.scatter(an_vol,an_rt,marker='o',s=200)

    for i, txt in enumerate(data_1.columns):
        ax.annotate(txt, (an_vol[i],an_rt[i]), xytext=(10,0), textcoords='offset points')
    ax.scatter(sdp,rp,marker='*',color='r',s=500, label='Maximum Sharpe ratio')
    ax.scatter(sdp_min,rp_min,marker='*',color='g',s=500, label='Minimum volatility')

    target = np.linspace(rp_min, 0.34, 50)
    efficient_portfolios = efficient_frontier(mean_returns, cov_matrix, target)
    ax.plot([p['fun'] for p in efficient_portfolios], target, linestyle='-.', color='black', label='efficient frontier')
    ax.set_title('Portfolio Optimization with Individual Stocks')
    ax.set_xlabel('annualised volatility')
    ax.set_ylabel('annualised returns')
    ax.legend(labelspacing=0.8)

# %%
display_ef_with_selected(mean_returns, cov_matrix, risk_free_rate)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-243-bf0566bbf245> in <module>
# ----> 1 display_ef_with_selected(mean_returns, cov_matrix, risk_free_rate)
#
# <ipython-input-241-bb6ed314f148> in display_ef_with_selected(mean_returns, cov_matrix, risk_free_rate)
#       1 def display_ef_with_selected(mean_returns, cov_matrix, risk_free_rate):
# ----> 2     max_sharpe = max_sharpe_ratio(mean_returns, cov_matrix, risk_free_rate)
#       3     sdp, rp = portfolio_annualised_performance(max_sharpe['x'], mean_returns, cov_matrix)
#       4     max_sharpe_allocation = pd.DataFrame(max_sharpe.x,index=data_1.columns,columns=['allocation'])
#       5     max_sharpe_allocation.allocation = [round(i*100,2)for i in max_sharpe_allocation.allocation]
#
# <ipython-input-232-a0cf177370eb> in max_sharpe_ratio(mean_returns, cov_matrix, risk_free_rate)
# ...

# %%
# negative ratio - patanjali , nifty50

# %%
# alphas = np.zeros(len(tickers_1))
# betas = np.zeros(len(tickers_1))
# def linear_regression(ticker_a,n):
#     X = log_returns[ticker_a].to_numpy().reshape(-1, 1)
#     Y = log_returns['Nifty50'].to_numpy().reshape(-1, 1)
#     lin_regr = LinearRegression()
#     lin_regr.fit(X, Y)
#     Y_pred = lin_regr.predict(X)
#     alpha = lin_regr.intercept_[0]
#     beta = lin_regr.coef_[0, 0]
#     alphas[n]=round(alpha, 5)
#     betas[n]=round(beta, 3)
#     fig, ax = plt.subplots()
#     ax.set_title("Alpha: " + str(round(alpha, 5)) + ", Beta: " + str(round(beta, 3)))
#     ax.scatter(X, Y)
#     ax.plot(X, Y_pred, c='r')

# %%
# for i in range (len(tickers_1)):
#     linear_regression(tickers_1[i],i)

# %%
# alphas.max()

# %%
# betas.max()

# %%
##PCA
##from sklearn.decomposition import PCA

# %%
##log_returns1=log_returns.iloc[1:,:20]

# %%
##log_returns1.reset_index(drop=True, inplace=True)

# %%
#log_returns1.dropna()
#log_returns1.info()

# %%
# def clean_dataset(log_returns1):
#     assert isinstance(log_returns1, pd.DataFrame), "df needs to be a pd.DataFrame"
#     log_returns1.dropna(inplace=True)
#     indices_to_keep = ~log_returns1.isin([np.nan, np.inf, -np.inf]).any(1)
#     return log_returns1[indices_to_keep].astype(np.float64)

# %%
# log_returns1.info()

# %%
# p = PCA()

# # fit on data

# p.fit(log_return)

# # access values and vectors

# print(p.components_.T)

# print()
# print(p.explained_variance_)

# # transform data

# BA = p.transform(log_return)

# print()

# print(BA)
# import numpy as np
# print()
# print(p.explained_variance_/np.sum(p.explained_variance_))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-130-b590ce5e4d5d> in <module>
#       3 # fit on data
#       4
# ----> 5 p.fit(log_return)
#       6
#       7 # access values and vectors
#
# ~\Anaconda\lib\site-packages\sklearn\decomposition\_pca.py in fit(self, X, y)
#     349             Returns the instance itself.
#     350         """
# --> 351         self._fit(X)
#     352         return self
#     353
#
# ~\Anaconda\lib\site-packages\sklearn\decomposition\_pca.py in _fit(self, X)
#     395                             'TruncatedSVD for a possible alternative.')
#     396
# --> 397         X = self._validate_data(X, dtype=[np.float64, np.float32],
#     398                                 ensure_2d=True, copy=self.copy)
#     399
#
# ~\Anaconda\lib\site-packages\sklearn\base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
# ...
